# %%
import pandas as pd

# %%
df=pd.read_csv('Downloads/banking.csv')

# %%
df
# Out:
#      Client ID              Name  Age  Location ID Joined Bank  \
# 0     IND81288     Raymond Mills   24        34324  06-05-2019
# 1     IND65833     Julia Spencer   23        42205  10-12-2001
# 2     IND47499    Stephen Murray   27         7314  25-01-2010
# 3     IND72498    Virginia Garza   40        34594  28-03-2019
# 4     IND60181   Melissa Sanders   46        41269  20-07-2012
# ...        ...               ...  ...          ...         ...
# 2995  IND66827         Earl Hall   82         8760  09-10-2014
# 2996  IND40556  Billy Williamson   44        32837  05-02-2009
# 2997  IND72414      Victor Black   70        36088  29-12-2009
# 2998  IND46652       Andrew Ford   56        24871  13-02-2006
# 2999  IND40216        Amy Nguyen   79        38518  08-12-2005
#
#           Banking Contact Nationality                     Occupation  \
# 0          Anthony Torres    American           Safety Technician IV
# ...

# %%
dfc=df.copy()

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
dfc['GenderId']=dfc['GenderId'].astype(object)

# %%
genreplace={
    1:'Male',
    2:'Female'
}
dfc['GenderId']=dfc['GenderId'].replace(genreplace)

# %%
dfc['GenderId']
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#          ...
# 2995    Female
# 2996    Female
# 2997    Female
# 2998    Female
# 2999    Female
# Name: GenderId, Length: 3000, dtype: object

# %%
dfrelations=pd.read_csv('Downloads/banking-realtionships.csv')
dfrelations
# Out:
#    BRId Banking Relationship
# 0     1               Retail
# 1     2        Institutional
# 2     3         Private Bank
# 3     4           Commercial

# %%
relations_dict=dfrelations.to_dict(orient='list')
relations_dict
# Out:
# {'BRId': [1, 2, 3, 4],
#  'Banking Relationship': ['Retail',
#   'Institutional',
#   'Private Bank',
#   'Commercial']}

# %%
rd={
    1:'Retail',
    2:'Institutional',
    3:'Private Bank',
    4:'Commercial'
}

# %%
dfc.columns
# Out:
# Index(['Client ID', 'Name', 'Age', 'Location ID', 'Joined Bank',
#        'Banking Contact', 'Nationality', 'Occupation', 'Fee Structure',
#        'Loyalty Classification', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Credit Card Balance', 'Bank Loans',
#        'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
#        'Foreign Currency Account', 'Business Lending', 'Properties Owned',
#        'Risk Weighting', 'BRId', 'GenderId', 'IAId'],
#       dtype='object')

# %%
dfc['BRId']=dfc['BRId'].replace(rd)

# %%
dfc
# Out:
#      Client ID              Name  Age  Location ID Joined Bank  \
# 0     IND81288     Raymond Mills   24        34324  06-05-2019
# 1     IND65833     Julia Spencer   23        42205  10-12-2001
# 2     IND47499    Stephen Murray   27         7314  25-01-2010
# 3     IND72498    Virginia Garza   40        34594  28-03-2019
# 4     IND60181   Melissa Sanders   46        41269  20-07-2012
# ...        ...               ...  ...          ...         ...
# 2995  IND66827         Earl Hall   82         8760  09-10-2014
# 2996  IND40556  Billy Williamson   44        32837  05-02-2009
# 2997  IND72414      Victor Black   70        36088  29-12-2009
# 2998  IND46652       Andrew Ford   56        24871  13-02-2006
# 2999  IND40216        Amy Nguyen   79        38518  08-12-2005
#
#           Banking Contact Nationality                     Occupation  \
# 0          Anthony Torres    American           Safety Technician IV
# ...

# %%
dfc.columns
# Out:
# Index(['Client ID', 'Name', 'Age', 'Location ID', 'Joined Bank',
#        'Banking Contact', 'Nationality', 'Occupation', 'Fee Structure',
#        'Loyalty Classification', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Credit Card Balance', 'Bank Loans',
#        'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
#        'Foreign Currency Account', 'Business Lending', 'Properties Owned',
#        'Risk Weighting', 'BRId', 'GenderId', 'IAId'],
#       dtype='object')

# %%
cols_to_drop=['Client ID','Name','Location ID','IAId','Banking Contact','Joined Bank']

# %%
dfc=dfc.drop(labels=cols_to_drop,axis=1)

# %%
dfc
# Out:
#       Age Nationality                     Occupation Fee Structure  \
# 0      24    American           Safety Technician IV          High
# 1      23     African            Software Consultant          High
# 2      27    European             Help Desk Operator          High
# 3      40    American                   Geologist II           Mid
# 4      46    American            Assistant Professor           Mid
# ...   ...         ...                            ...           ...
# 2995   82    American       Accounting Assistant III          High
# 2996   44    European                      Paralegal           Mid
# 2997   70    American                Statistician IV           Low
# 2998   56    European  Human Resources Assistant III           Mid
# 2999   79    American            Biostatistician III          High
#
#      Loyalty Classification  Estimated Income  Superannuation Savings  \
# 0                      Jade          75384.77                17677.95
# ...

# %%
dfc['Total_Balance'] = (
    dfc['Checking Accounts'] +
    dfc['Saving Accounts'] +
    dfc['Bank Deposits']
)

# %%
dfc['Credit_Utilization'] = (
    dfc['Credit Card Balance'] /
    (dfc['Amount of Credit Cards'] + 1)
)

# %%
dfc['Loan_to_Income'] = dfc['Bank Loans'] / (dfc['Estimated Income'] + 1)

# %%
dfc
# Out:
#       Age Nationality                     Occupation Fee Structure  \
# 0      24    American           Safety Technician IV          High
# 1      23     African            Software Consultant          High
# 2      27    European             Help Desk Operator          High
# 3      40    American                   Geologist II           Mid
# 4      46    American            Assistant Professor           Mid
# ...   ...         ...                            ...           ...
# 2995   82    American       Accounting Assistant III          High
# 2996   44    European                      Paralegal           Mid
# 2997   70    American                Statistician IV           Low
# 2998   56    European  Human Resources Assistant III           Mid
# 2999   79    American            Biostatistician III          High
#
#      Loyalty Classification  Estimated Income  Superannuation Savings  \
# 0                      Jade          75384.77                17677.95
# ...

# %%
dfc.columns
# Out:
# Index(['Age', 'Nationality', 'Occupation', 'Fee Structure',
#        'Loyalty Classification', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Credit Card Balance', 'Bank Loans',
#        'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
#        'Foreign Currency Account', 'Business Lending', 'Properties Owned',
#        'Risk Weighting', 'BRId', 'GenderId', 'Total_Balance',
#        'Credit_Utilization', 'Loan_to_Income'],
#       dtype='object')

# %%
dfc=dfc.drop(labels=['Checking Accounts','Saving Accounts','Bank Loans','Bank Deposits','Credit Card Balance'],axis=1)

# %%
dfc
# Out:
#       Age Nationality                     Occupation Fee Structure  \
# 0      24    American           Safety Technician IV          High
# 1      23     African            Software Consultant          High
# 2      27    European             Help Desk Operator          High
# 3      40    American                   Geologist II           Mid
# 4      46    American            Assistant Professor           Mid
# ...   ...         ...                            ...           ...
# 2995   82    American       Accounting Assistant III          High
# 2996   44    European                      Paralegal           Mid
# 2997   70    American                Statistician IV           Low
# 2998   56    European  Human Resources Assistant III           Mid
# 2999   79    American            Biostatistician III          High
#
#      Loyalty Classification  Estimated Income  Superannuation Savings  \
# 0                      Jade          75384.77                17677.95
# ...

# %%
dfc.isnull().sum()
# Out:
# Age                         0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# Total_Balance               0
# Credit_Utilization          0
# Loan_to_Income              0
# dtype: int64

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3000 non-null   int64
#  1   Nationality               3000 non-null   object
#  2   Occupation                3000 non-null   object
#  3   Fee Structure             3000 non-null   object
#  4   Loyalty Classification    3000 non-null   object
#  5   Estimated Income          3000 non-null   float64
#  6   Superannuation Savings    3000 non-null   float64
#  7   Amount of Credit Cards    3000 non-null   int64
#  8   Foreign Currency Account  3000 non-null   float64
#  9   Business Lending          3000 non-null   float64
#  10  Properties Owned          3000 non-null   int64
#  11  Risk Weighting            3000 non-null   int64
#  12  BRId                      3000 non-null   object
# ...

# %%
dfc['Risk Weighting'].value_counts()
# Out:
# Risk Weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64

# %%
x=dfc.drop(labels=['Risk Weighting'],axis=1)
y=dfc[['Risk Weighting']]

# %%
x
# Out:
#       Age Nationality                     Occupation Fee Structure  \
# 0      24    American           Safety Technician IV          High
# 1      23     African            Software Consultant          High
# 2      27    European             Help Desk Operator          High
# 3      40    American                   Geologist II           Mid
# 4      46    American            Assistant Professor           Mid
# ...   ...         ...                            ...           ...
# 2995   82    American       Accounting Assistant III          High
# 2996   44    European                      Paralegal           Mid
# 2997   70    American                Statistician IV           Low
# 2998   56    European  Human Resources Assistant III           Mid
# 2999   79    American            Biostatistician III          High
#
#      Loyalty Classification  Estimated Income  Superannuation Savings  \
# 0                      Jade          75384.77                17677.95
# ...

# %%
y
# Out:
#       Risk Weighting
# 0                  2
# 1                  3
# 2                  3
# 3                  4
# 4                  3
# ...              ...
# 2995               3
# 2996               2
# 2997               2
# 2998               1
# 2999               1
#
# [3000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
categorical_cols = x.select_dtypes(include='object').columns
numerical_cols = x.select_dtypes(exclude='object').columns

# %%
categorical_cols, numerical_cols
# Out:
# (Index(['Nationality', 'Occupation', 'Fee Structure', 'Loyalty Classification',
#         'BRId', 'GenderId'],
#        dtype='object'),
#  Index(['Age', 'Estimated Income', 'Superannuation Savings',
#         'Amount of Credit Cards', 'Foreign Currency Account',
#         'Business Lending', 'Properties Owned', 'Total_Balance',
#         'Credit_Utilization', 'Loan_to_Income'],
#        dtype='object'))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols)
    ]
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

lr_pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('model', LogisticRegression(
        max_iter=3000,
        class_weight='balanced',
        solver='lbfgs',
        multi_class='ovr'
    ))
])

lr_pipeline.fit(X_train, y_train)
# Out:
# C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Age', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Foreign Currency Account',
#        'Business Lending', 'Properties Owned', 'Total_Balance',
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score

y_pred_lr = lr_pipeline.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))
# Out:
# Accuracy: 0.4816666666666667
#               precision    recall  f1-score   support
#
#            1       0.66      0.84      0.74       167
#            2       0.64      0.40      0.49       245
#            3       0.28      0.28      0.28        92
#            4       0.23      0.33      0.27        64
#            5       0.08      0.12      0.09        32
#
#     accuracy                           0.48       600
#    macro avg       0.38      0.39      0.38       600
# weighted avg       0.52      0.48      0.48       600

# %%
from sklearn.metrics import roc_auc_score

y_prob_lr = lr_pipeline.predict_proba(X_test)

roc_auc_lr = roc_auc_score(
    y_test,
    y_prob_lr,
    multi_class='ovr',
    average='macro'
)

roc_auc_lr
# Out:
# np.float64(0.7595377122704555)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('model', RandomForestClassifier(
        n_estimators=500,
        random_state=42,
        class_weight='balanced'
    ))
])

rf_pipeline.fit(X_train, y_train)
# Out:
# C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Age', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Foreign Currency Account',
#        'Business Lending', 'Properties Owned', 'Total_Balance',
#        'Credit_Utilization', 'Loan_to_Income'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score

y_pred_rf = rf_pipeline.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Accuracy: 0.595
#               precision    recall  f1-score   support
#
#            1       0.80      0.74      0.77       167
#            2       0.55      0.86      0.67       245
#            3       0.38      0.14      0.21        92
#            4       0.38      0.16      0.22        64
#            5       0.50      0.03      0.06        32
#
#     accuracy                           0.59       600
#    macro avg       0.52      0.38      0.38       600
# weighted avg       0.57      0.59      0.54       600

# %%
from sklearn.metrics import roc_auc_score

y_prob_rf = rf_pipeline.predict_proba(X_test)

roc_auc_rf = roc_auc_score(
    y_test,
    y_prob_rf,
    multi_class='ovr',
    average='macro'
)

roc_auc_rf
# Out:
# np.float64(0.8470217471702185)

# %%
risk_map = {
    1: 0,   # Low
    2: 0,   # Low
    3: 1,   # Medium
    4: 2,   # High
    5: 2    # High
}

dfc['Risk_Band'] = dfc['Risk Weighting'].map(risk_map)

# %%
X = dfc.drop(columns=['Risk Weighting', 'Risk_Band', 'BRId'])
y = dfc['Risk_Band']

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import imblearn

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression

smote_lr = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('model', LogisticRegression(
        max_iter=3000,
        solver='lbfgs',
        multi_class='ovr'
    ))
])

smote_lr.fit(X_train, y_train)
# Out:
# C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Age', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Foreign Currency Account',
#        'Business Lending', 'Properties Owned', 'Total_Balance',
# ...

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'model__C': [0.01, 0.1, 1, 10],
    'model__penalty': ['l2']
}

grid_lr = GridSearchCV(
    smote_lr,
    param_grid,
    scoring='f1_macro',
    cv=5,
    n_jobs=-1
)

grid_lr.fit(X_train, y_train)
# Out:
# C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
# ...

# %%
best_lr = grid_lr.best_estimator_
best_lr
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Age', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Foreign Currency Account',
#        'Business Lending', 'Properties Owned', 'Total_Balance',
#        'Credit_Utilization', 'Loan_to_Income'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   Index(['Nationality', 'Occupation', 'Fee Structure', 'Loyalty Classification',
#        'BRId', 'GenderId'],
#       dtype='object'))])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('model', GradientBoostingClassifier(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=3,
        random_state=42
    ))
])

gb_pipeline.fit(X_train, y_train)
# Out:
# C:\Users\SOHAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Age', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Foreign Currency Account',
#        'Business Lending', 'Properties Owned', 'Total_Balance',
#        'Credit_Utilization', 'Loan_to_Income'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
# ...

# %%
y_prob = best_lr.predict_proba(X_test)

# Example: lower threshold for High Risk
custom_preds = (y_prob[:, 2] > 0.35).astype(int)

# %%
from sklearn.metrics import classification_report, roc_auc_score

def evaluate(model):
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)

    print(classification_report(y_test, y_pred))
    print(
        "ROC-AUC:",
        roc_auc_score(y_test, y_prob, multi_class='ovr', average='macro')
    )

# %%
evaluate(gb_pipeline)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.79      0.75      0.77       167
#            2       0.63      0.80      0.70       245
#            3       0.45      0.35      0.39        92
#            4       0.36      0.23      0.28        64
#            5       0.36      0.16      0.22        32
#
#     accuracy                           0.62       600
#    macro avg       0.52      0.46      0.47       600
# weighted avg       0.60      0.62      0.60       600
#
# ROC-AUC: 0.8546724217082096

# %%
evaluate(best_lr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.66      0.91      0.76       167
#            2       0.71      0.39      0.50       245
#            3       0.32      0.26      0.29        92
#            4       0.23      0.33      0.27        64
#            5       0.15      0.31      0.20        32
#
#     accuracy                           0.50       600
#    macro avg       0.41      0.44      0.40       600
# weighted avg       0.55      0.50      0.50       600
#
# ROC-AUC: 0.7895604353665213

# %%
evaluate(smote_lr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.66      0.85      0.74       167
#            2       0.62      0.33      0.43       245
#            3       0.26      0.22      0.24        92
#            4       0.22      0.38      0.28        64
#            5       0.12      0.28      0.17        32
#
#     accuracy                           0.46       600
#    macro avg       0.38      0.41      0.37       600
# weighted avg       0.51      0.46      0.46       600
#
# ROC-AUC: 0.7312571737782847

# %%
evaluate(lr_pipeline)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.66      0.84      0.74       167
#            2       0.64      0.40      0.49       245
#            3       0.28      0.28      0.28        92
#            4       0.23      0.33      0.27        64
#            5       0.08      0.12      0.09        32
#
#     accuracy                           0.48       600
#    macro avg       0.38      0.39      0.38       600
# weighted avg       0.52      0.48      0.48       600
#
# ROC-AUC: 0.7595377122704555

# %%
evaluate(rf_pipeline)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.74      0.77       167
#            2       0.55      0.86      0.67       245
#            3       0.38      0.14      0.21        92
#            4       0.38      0.16      0.22        64
#            5       0.50      0.03      0.06        32
#
#     accuracy                           0.59       600
#    macro avg       0.52      0.38      0.38       600
# weighted avg       0.57      0.59      0.54       600
#
# ROC-AUC: 0.8470217471702185

# %%
gb_model = gb_pipeline.named_steps['model']
importances = gb_model.feature_importances_

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(gb_pipeline, X_test, y_test)

# %%
sample_customer = X_test.iloc[[0]]  
predicted_risk = gb_pipeline.predict(sample_customer)

predicted_risk[0]
# Out:
# np.int64(4)

# %%
gb_pipeline.predict_proba(sample_customer)
# Out:
# array([[0.00567909, 0.23634608, 0.30481278, 0.33807532, 0.11508673]])

# %%
risk = int(predicted_risk[0])
confidence = gb_pipeline.predict_proba(sample_customer).max()

print(f"Predicted Risk Level: {risk}")
print(f"Model Confidence: {confidence:.2%}")
# Out:
# Predicted Risk Level: 4
# Model Confidence: 33.81%
